# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/Car_Purchasing_Data.csv')

# %%
df.head()
# Out:
#      Customer Name                                    Customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      Net Worth  Car Purchase Amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
df.isna().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
df.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df.nunique()
# Out:
# Customer Name          498
# Customer e-mail        500
# Country                211
# Gender                   2
# Age                    500
# Annual Salary          500
# Credit Card Debt       500
# Net Worth              500
# Car Purchase Amount    500
# dtype: int64

# %%
# 나이가 가장 어린 고객의 정보 조회
df[df['Age'] == df['Age'].min()]
# Out:
#     Customer Name                          Customer e-mail  \
# 444        Camden  Aliquam.adipiscing.lobortis@loremut.net
#
#                  Country  Gender   Age  Annual Salary  Credit Card Debt  \
# 444  Congo (Brazzaville)       1  20.0    70467.29492             100.0
#
#        Net Worth  Car Purchase Amount
# 444  494606.6334          28645.39425

# %%
# 연봉이 가장 높은 고객의 정보
df[df['Annual Salary'] == df['Annual Salary'].max()]
# Out:
#     Customer Name     Customer e-mail  Country  Gender        Age  \
# 28  Gemma Hendrix  lobortis@non.co.uk  Denmark       1  46.124036
#
#     Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount
# 28       100000.0       17452.92179  188032.0778          58350.31809

# %%
# 상관관계분석
corr = df.corr(numeric_only=True)
corr
# Out:
#                        Gender       Age  Annual Salary  Credit Card Debt  \
# Gender               1.000000 -0.064481      -0.036499          0.024193
# Age                 -0.064481  1.000000       0.000130          0.034721
# Annual Salary       -0.036499  0.000130       1.000000          0.049599
# Credit Card Debt     0.024193  0.034721       0.049599          1.000000
# Net Worth           -0.008395  0.020356       0.014767         -0.049378
# Car Purchase Amount -0.066408  0.632865       0.617862          0.028882
#
#                      Net Worth  Car Purchase Amount
# Gender               -0.008395            -0.066408
# Age                   0.020356             0.632865
# Annual Salary         0.014767             0.617862
# Credit Card Debt     -0.049378             0.028882
# Net Worth             1.000000             0.488580
# Car Purchase Amount   0.488580             1.000000

# %%
sns.heatmap(corr, vmax=1, vmin=-1, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
plt.show()

# %%
# 나이와 연봉이 자동차 구매 금액과 가장 관련이 높다.

# %%
df.columns
# Out:
# Index(['Customer Name', 'Customer e-mail', 'Country', 'Gender', 'Age',
#        'Annual Salary', 'Credit Card Debt', 'Net Worth',
#        'Car Purchase Amount'],
#       dtype='object')

# %%
sns.pairplot(data=df, vars=['Age','Annual Salary','Credit Card Debt','Car Purchase Amount', 'Net Worth'])
plt.show()

# %%
# 자동차 구매 금액을 예측하는 AI

# %%
df.isna().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
df.head()
# Out:
#      Customer Name                                    Customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      Net Worth  Car Purchase Amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
df['Country'].nunique()
# Out:
# 211

# %%
df['Country'].value_counts()
# Out:
# Country
# Mauritania                                      6
# Israel                                          6
# Bolivia                                         6
# Kyrgyzstan                                      5
# Samoa                                           5
#                                                ..
# Ukraine                                         1
# New Zealand                                     1
# Saint Helena, Ascension and Tristan da Cunha    1
# Malaysia                                        1
# marlal                                          1
# Name: count, Length: 211, dtype: int64

# %%
X = df.loc[:, 'Gender':'Net Worth']
X
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
y = df['Car Purchase Amount']
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
# 수치예측하는 것이므로, Regression 모델을 사용해야 한다.
# 1. 머신러닝 : 리니어 리그레션, 랜덤포레스트 리그레션, XGboost 리그레션
# 2. 딥러닝 : ANN

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([50442.55378158, 33637.67676393, 60223.43489235, 32555.60730525,
#        55173.49639425, 49257.88835254, 64189.23023507, 49398.91003456,
#        43991.77206729, 63138.25445831, 47761.78275665, 42776.71127041,
#        55168.08909116, 47381.31271217, 46400.89342895, 49049.94291444,
#        52984.40744436, 34802.31812166, 50540.52154217, 43904.28483005,
#        44649.41196153, 52479.96243338, 37304.08038318, 65594.59127251,
#        37365.75671717, 49510.75241015, 51223.98014241, 25252.07973877,
#        41914.75143606, 40095.69463197, 42499.83559233, 48382.37211925,
#        47935.71626581, 35852.05057174, 36638.42228174, 39331.33117286,
#        42010.58996872, 54073.57242545, 42926.22898846, 40103.57060831,
#        57302.22187346, 46643.5015326 , 56973.7984475 , 31087.50874651,
#        52993.69433468, 41813.41088662, 51868.41472728, 39002.91870614,
#        27809.1316575 , 36366.96959485, 39132.84053379, 30721.06759704,
# ...

# %%
((y_test - y_pred)**2).mean()
# Out:
# np.float64(2.7933992939706864)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.7933992939706864

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor2 = RandomForestRegressor()

# %%
regressor2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = regressor2.predict(X_test)
y_pred2
# Out:
# array([47600.4790304, 36430.1593237, 57906.6690798, 33084.3748389,
#        53165.5856715, 50222.5805005, 62876.5099108, 49512.8205833,
#        44994.4969448, 60053.1655281, 45159.5431864, 43465.4079826,
#        54894.1988633, 45723.1923211, 39319.94405  , 48501.5507164,
#        52113.9578542, 34220.7152292, 49266.7730725, 44841.0118854,
#        44780.2242562, 50344.0037365, 38925.2367245, 63760.7172665,
#        39851.6322272, 50795.2281388, 48903.2407006, 24726.7296689,
#        41465.2332456, 42755.0873186, 41226.9260266, 47255.4916853,
#        46470.7657133, 37023.8706149, 38381.1812967, 40232.5722736,
#        41610.6767686, 54041.6912592, 42504.0044351, 41258.8662629,
#        54530.9731662, 48324.3581415, 53715.3280598, 33013.3050501,
#        51403.2141858, 41990.9455984, 48981.2527948, 39027.1033881,
#        31999.8774664, 38524.1430005, 39830.9866267, 32565.5895813,
#        59395.2487601, 57644.3839106, 63316.5847493, 39284.6178477,
# ...

# %%
((y_test - y_pred2)**2).mean()
# Out:
# np.float64(5777025.69288755)

# %%
mean_squared_error(y_test, y_pred2)
# Out:
# 5777025.69288755

# %%
from xgboost import XGBRegressor

# %%
regressor3 = XGBRegressor()

# %%
regressor3.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred3 = regressor3.predict(X_test)

# %%
mean_squared_error(y_test, y_pred3)
# Out:
# 5160166.040505806

# %%
### R2로 0~1 사이 값으로도 나타내보자

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9999999667332884

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.9312011540042362

# %%
r2_score(y_test, y_pred3)
# Out:
# 0.9385473619806801

# %%
# 가장 성능이 뛰어난 regressor를 파일로 저장한다.
import joblib

# %%
joblib.dump(regressor, './model/regressor.pkl')
# Out:
# ['./model/regressor.pkl']
